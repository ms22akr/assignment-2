# %% [markdown]
# ### Country-by-Country Climate Change Analysis: Exploring Key Indicators through Data Analysis

# %%
# Import Data
import pandas as pd
df = pd.read_csv("WDI.csv")

# %% [markdown]
# ### Summerize Climate Data

# %%
df.head()
# Out:
#    year    country               region code  Agricultural land (sq. km)  \
# 0  2016  Australia  East Asia & Pacific  AUS                   3426020.0
# 1  2015  Australia  East Asia & Pacific  AUS                   3481190.0
# 2  2011  Australia  East Asia & Pacific  AUS                   3961210.0
# 3  2012  Australia  East Asia & Pacific  AUS                   3870760.0
# 4  2013  Australia  East Asia & Pacific  AUS                   3717750.0
#
#    access to electricity   HYRO    NGAS   PETR    RNEW  ...  CO2EGFT    FDI  \
# 0                  100.0    NaN     NaN    NaN     NaN  ...   15.915  3.561
# 1                  100.0  5.296  20.795  2.695  13.638  ...   15.863  3.472
# 2                  100.0  6.599  19.297  2.288  10.427  ...   17.295  4.688
# 3                  100.0  5.586  19.343  1.509  10.593  ...   17.022  3.720
# 4                  100.0  7.279  20.453  2.568  13.264  ...   16.442  3.455
#
#    Urban population growth  Population growth  CO2 emissions (kt)  \
# ...

# %%
# Fill all null value with zero
df=df.fillna(0)

# %%
df.shape
# Out:
# (462, 22)

# %%
df.describe()
# Out:
#               year  Agricultural land (sq. km)  access to electricity  \
# count   462.000000                4.620000e+02             462.000000
# mean   2010.500000                1.832816e+06              79.068028
# std       6.351166                2.458954e+06              29.490441
# min    2000.000000                0.000000e+00               0.000000
# 25%    2005.000000                1.620000e+05              65.910784
# 50%    2010.500000                4.735135e+05             100.000000
# 75%    2016.000000                2.711806e+06             100.000000
# max    2021.000000                1.036242e+07             100.000000
#
#              HYRO        NGAS        PETR        RNEW   Energy use  \
# count  462.000000  462.000000  462.000000  462.000000   462.000000
# mean    15.192325   14.662478    4.416457   17.723177  2181.215225
# std     23.555092   20.453084    8.518416   24.592612  2569.685620
# ...

# %% [markdown]
# ### Summerize data with aggrete Countries and Region
#
# #### Summary of Countries with Agriculture Land

# %%
# Aggregating Data with Pandas .groupby()
a0=df.groupby('country')[['Agricultural land (sq. km)']].describe()
round(a0,0)
# Out:
#                         Agricultural land (sq. km)                             \
#                                              count       mean        std  min
# country
# Australia                                     22.0  3740672.0   899099.0  0.0
# Bangladesh                                    22.0    89575.0    20103.0  0.0
# Canada                                        22.0   566653.0   127626.0  0.0
# China                                         22.0  5035998.0  1124925.0  0.0
# France                                        22.0   277423.0    62082.0  0.0
# Germany                                       22.0   160593.0    35903.0  0.0
# India                                         22.0  1716422.0   383401.0  0.0
# Israel                                        22.0     5271.0     1269.0  0.0
# Italy                                         22.0   133433.0    31225.0  0.0
# New Zealand                                   22.0   110588.0    28119.0  0.0
# ...

# %% [markdown]
# This appears to be a table showing descriptive statistics for agricultural land (measured in square kilometers) for various countries. The statistics include the count, mean, standard deviation, minimum value, 25th percentile value, median value (50th percentile), 75th percentile value and maximum value. According to the data you provided, **Sub-Saharan Africa** has the highest mean agricultural land with a value of **9645435.0 square kilometers**. According to the data you provided, **Israel** has the lowest mean agricultural land with a value of **5271.0 square kilometers**.

# %% [markdown]
# #### Summary of Region with Agriculture Land

# %%
# Aggregating Data with Pandas .groupby()
aa=df.groupby('region')[['Agricultural land (sq. km)']].describe()
round(aa,3)
# Out:
#                            Agricultural land (sq. km)               \
#                                                 count         mean
# region
# Aggregates                                       66.0  3212036.412
# East Asia & Pacific                              66.0  2962419.424
# Europe & Central Asia                            88.0   184054.123
# Middle East & North Africa                       44.0   831182.254
# North America                                    44.0  2234028.439
# South Asia                                       66.0   717440.496
# Sub-Saharan Africa                               88.0  2736699.756
#
#                                                                      \
#                                     std  min        25%         50%
# region
# Aggregates                  1157140.849  0.0  2704682.5  2711567.37
# East Asia & Pacific         2254604.910  0.0   114877.5  3803145.00
# Europe & Central Asia         69935.617  0.0   151815.0   169655.00
# ...

# %% [markdown]
# According to the data you provided, the region with the highest mean value is **East Asia & Pacific** with a mean value of **2962419.424**. According to the data you provided, the region with the lowest mean value is **Europe & Central Asia** with a mean value of **184054.123**. We can see that the mean agricultural land in square kilometers for the 22 observations in the global aggregate is approximately 9.6 million with a standard deviation of about 2.1 million, and the minimum value is Sub-Saharan Africa while the maximum value is 1.04 million. The 25th and 75th percentiles are 10.0 million and 10.16 million, respectively.

# %% [markdown]
# #### Summary of Region and Countries with Agriculture Land

# %% [markdown]
# #### Summary of Countries with Energy use

# %%
# Aggregating country with Energy use
df.groupby('country')[['Energy use']].describe()
# Out:
#                         Energy use                                             \
#                              count         mean          std  min         25%
# country
# Australia                     22.0  4115.938227  2583.792763  0.0  1333.67050
# Bangladesh                    22.0   124.087818    89.851059  0.0     0.00000
# Canada                        22.0  5849.364636  3673.187153  0.0  1907.83550
# China                         22.0  1082.161591   850.459770  0.0     0.00000
# France                        22.0  2939.733318  1851.648102  0.0   914.77200
# Germany                       22.0  2908.901636  1827.129266  0.0   944.86550
# India                         22.0   341.062136   246.571484  0.0     0.00000
# Israel                        22.0  2111.472727  1327.298493  0.0   665.36225
# Italy                         22.0  2129.549409  1352.619352  0.0   603.62100
# New Zealand                   22.0  3094.098364  1944.043945  0.0  1011.82950
# ...

# %% [markdown]
# From the table, we can see that the energy use varies widely across countries, with the mean energy use ranging from 124.09 in Bangladesh to 8455.55 in Canada. Some countries have a wide range of energy use, as indicated by the difference between the minimum and maximum values, while others have a relatively narrow range.
#
# The table also shows that the standard deviation (a measure of the variability of the data) is generally quite high for energy use across countries. This indicates that there is a lot of variability in energy use both within and between countries.

# %% [markdown]
# #### Summary of Region with Energy use

# %%
df.groupby('region')[['Energy use']].describe()
# Out:
#                            Energy use                                      \
#                                 count         mean          std  min  25%
# region
# Aggregates                       66.0  2026.461045  3131.295535  0.0  0.0
# East Asia & Pacific              66.0  2764.066061  2285.695515  0.0  0.0
# Europe & Central Asia            88.0  2604.684432  1667.012633  0.0  0.0
# Middle East & North Africa       44.0  2933.955023  2253.355486  0.0  0.0
# North America                    44.0  5628.881955  3510.053423  0.0  0.0
# South Asia                       66.0   253.017091   211.571434  0.0  0.0
# Sub-Saharan Africa               88.0   782.618864   891.681194  0.0  0.0
#
#
#                                   50%         75%       max
# region
# Aggregates                   432.4670   565.47900  8077.287
# East Asia & Pacific         2214.2990  4522.64900  5964.666
# Europe & Central Asia       3172.8665  3886.01725  4300.955
# ...

# %% [markdown]
# This table shows that, we can observe that the mean energy use is highest in North America (5628.88) and lowest in South Asia (253.02). The standard deviation is highest in Aggregates (3131.30) and lowest in Europe & Central Asia (1667.01). We can also observe that the energy use in some regions has a wide range, such as Aggregates and Middle East & North Africa, while the range is narrow for other regions, such as Europe & Central Asia.

# %% [markdown]
# #### Summary of Region with CO2 emissions (kt)

# %% [markdown]
# #### Summary of Countries with Population Growth Rate

# %% [markdown]
# #### Summary of Countries with Access to Electricity

# %% [markdown]
# #### Summary of Year with Access to Electricity

# %% [markdown]
# #### Summary of Year with Eelectric Power Consumption

# %% [markdown]
# ### Correlation Analysis
#
# #### Correlation between the two Energy use and population growth

# %%
# calculate the correlation between the two Energy use and population growth
corr = df['Energy use'].corr(df['Population growth'])
print(round(corr,4))
# Out:
# -0.1802

# %% [markdown]
# A correlation of -0.1802 between Energy use and population growth for all countries from 2000 to 2021 indicates a weak negative correlation between these two variables. This means that as population growth increases, energy use tends to decrease slightly, but the relationship between the two is not very strong.

# %% [markdown]
# #### Correlation between the two Energy use and access to electricity

# %%
# calculate the correlation between the two Energy use and access to electricity
corr = df['Energy use'].corr(df['access to electricity'])
print(round(corr,4))
# Out:
# 0.4952

# %% [markdown]
# The correlation coefficient measures the strength and direction of a linear relationship between two variables. A value of 0.4952 indicates a moderate positive correlation between energy use and access to electricity for all countries from 2000 to 2021. This means that as energy use increases, access to electricity also tends to increase, and vice versa.

# %% [markdown]
# #### Correlation between the two CO2 emissions (kt) and electric power consumption

# %%
# calculate the correlation between the two CO2 emissions (kt) and electric power consumption
corr = df['CO2 emissions (kt)'].corr(df['EPC'])
print(round(corr,4))
# Out:
# 0.2078

# %% [markdown]
# The correlation coefficient measures the strength and direction of a linear relationship between two variables. A value of 0.2078 indicates a weak positive correlation between CO2 emissions (measured in kilotons) and electric power consumption. This means that as CO2 emissions increase, electric power consumption also tends to increase, but the relationship is not very strong.

# %% [markdown]
# #### Correlation between the two CO2 emissions (kt) and Agricultural land (sq. km)

# %%
# Calculate the correlation between the two CO2 emissions (kt) and Agricultural land (sq. km)
corr = df['CO2 emissions (kt)'].corr(df['Agricultural land (sq. km)'])
print(round(corr,4))
# Out:
# 0.4964

# %% [markdown]
# A correlation coefficient of 0.4964 indicates a moderately positive correlation between the two variables, CO2 emissions (kt) and Agricultural land (sq. km). This means that as the value of one variable increases, the value of the other variable tends to increase as well, but not necessarily at the same rate.

# %% [markdown]
# ### Data Visualization

# %%
import numpy as np
import random as rand
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### Yearly climate change Power Consumption and Energy use from 2000-2021

# %%
sns.lineplot(x=df["year"],y=df["EPC"],label="EPC")
sns.lineplot(x=df["year"],y=df["Energy use"],label="Energy use")
# add labels and title to the plot
plt.xlabel('Year')
plt.ylabel('')
plt.title('Yearly climate change Power Consumption and Energy use from 2000-2021')

# display the plot
plt.show()

# %% [markdown]
# This plot shows the yearly change in energy use related to climate change from 2000 to 2021. There is a significant decrease in energy use, close to 0, between 2015 and 2021. Overall, this plot shows a decline in energy use for all countries from 2000 to 2021.

# %% [markdown]
# #### Yearly climate change  FDI and GDP per using all countires from 2000-2021

# %%
sns.lineplot(x=df["year"],y=df["FDI"],label="FDI")
sns.lineplot(x=df["year"],y=df["GDP  Per"],label="GDP  Per")
# add labels and title to the plot
plt.xlabel('Year')
plt.ylabel('')
plt.title('Yearly climate change  FDI and GDP per using all countires from 2000-2021')

# display the plot
plt.show()

# %% [markdown]
# This plot shows the yearly change in Foreign Direct Investment (FDI) net inflows as a percentage of GDP and GDP per capita related to climate change from 2000 to 2021. There is significant variation in FDI and GDP per capita from 2000 to 2015, with ups and downs. However, from 2015 to 2021, there is a sudden increase. Overall, this plot shows that there is no constant trend in FDI and GDP per capita for all countries from 2000 to 2021

# %% [markdown]
# #### Energy use all countires from 2000-2021

# %%
plt.figure(figsize=(10,5))
fig, ax = plt.subplots()
ax.bar(df["country"],df["Energy use"])
ax.set_xlabel('Countries')
ax.set_ylabel('Energy use')
plt.title(label='Energy use all countires from 2000-2021')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# The bar plot graphically represents the energy consumption of various countries and reveals that Bangladesh has the lowest energy consumption, while Canada has the highest. This visualization enables us to easily identify the countries with the highest and lowest energy usage and make meaningful comparisons.
#
# By analyzing the plot, we can gain valuable insights into the impact of different countries on energy consumption from 2000 to 2021. Overall, this bar plot proves to be an efficient tool for visualizing the relationship between countries and their energy use.

# %% [markdown]
# #### Access to electricity all countires from 2000-2021

# %%
plt.figure(figsize=(10,5))
fig, ax = plt.subplots()
ax.bar(df["country"],df["access to electricity"])
ax.set_xlabel('Countries')
ax.set_ylabel('Access to electricity')
plt.title(label='Access to electricity all countires from 2000-2021')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# The bar plot graphically represents the Accesss to electricity of various countries and reveals that Zambia has the lowest Accesss to electricity, while Australia has the highest. This visualization enables us to easily identify the countries with the highest and lowest Accesss to electricity and make meaningful comparisons.
#
# By analyzing the plot, we can gain valuable insights into the impact of different countries on Accesss to electricity from 2000 to 2021. . Overall, this bar plot proves to be an efficient tool for visualizing the relationship between countries and their Accesss to electricity.

# %% [markdown]
# #### CO2 emissions (kt) all countires from 2000-2021

# %%
plt.figure(figsize=(10,5))
fig, ax = plt.subplots()
ax.bar(df["country"],df["CO2 emissions (kt)"])
ax.set_xlabel('Countries')
ax.set_ylabel('CO2 emissions (kt)')
plt.title(label='CO2 emissions (kt) all countires from 2000-2021')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# To create a bar plot in Python using pyplot, we can set the x-axis to represent CO2 emissions (in kilotons) and the y-axis to represent different countries. This plot provides a visual representation of the CO2 emissions of various countries from 2000 to 2021.
#
# The plot reveals that Zimbabwe, Zambia, and New Zealand have the lowest CO2 emissions (in kilotons) while China and North Africa have the highest CO2 emissions. It is evident that this plot provides valuable information regarding the variation in CO2 emissions across different countries over the years.
#
# In summary, the bar plot created using pyplot is an effective tool for visualizing the CO2 emissions of different countries over the years. It highlights the countries with the lowest and highest CO2 emissions and helps in analyzing the patterns and trends in CO2 emissions across the world.

# %% [markdown]
# #### Agricultural land (sq. km) all countires from 2000-2021

# %%
plt.figure(figsize=(10,5))
fig, ax = plt.subplots()
ax.bar(df["country"],df["Agricultural land (sq. km)"])
ax.set_xlabel('Countries')
ax.set_ylabel('Agricultural land (sq. km)')
plt.title(label='Agricultural land (sq. km) all countires from 2000-2021')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# To create a bar plot using pyplot, we can set the x-axis as Agricultural land (in sq. km) and the y-axis as the countries. This plot can help us visualize the Agricultural land (in sq. km) of different countries from 2000 to 2021.
#
# From the plot, it is evident that Israel and Bangladesh have the lowest Agricultural land (in sq. km), while the highest Agricultural land (in sq. km) can be seen in South Asia. This bar plot provides a clear representation of the Agricultural land (in sq. km) across all countries and allows for easy comparison between them.

# %% [markdown]
# #### Mathene emission and Electricity production from hydroelectric sources all Countries

# %%
plt.figure(figsize=(15,7))
fig, ax = plt.subplots()
ax.bar(df["country"],df["Mathene emission"],label="Mathene emission")
ax.bar(df["country"],df["HYRO"],label="HYRO")
ax.set_xlabel('Country')
ax.set_ylabel('')
plt.title(label='Mathene emission and Electricity production from hydroelectric sources all Countries')
plt.xticks(rotation = 75)
plt.legend()
plt.show()

# %% [markdown]
# From the plot, it is Mathene emission and Electricity production from hydroelectric sources all Countries, while the highest Mathene emission and Electricity production from hydroelectric sources can be seen in Zambia. This bar plot provides a clear representation of the Mathene emission and Electricity production from hydroelectric sources across all countries and allows for easy comparison between them.

# %% [markdown]
# ### Mathene emission and Electricity production from hydroelectric sources all region

# %%
plt.figure(figsize=(15,7))
fig, ax = plt.subplots()
ax.bar(df["region"],df["Mathene emission"],label="Mathene emission")
ax.bar(df["region"],df["HYRO"],label="HYRO")
ax.set_xlabel('Region')
ax.set_ylabel('')
plt.title(label='Mathene emission and Electricity production from hydroelectric sources all region')
plt.xticks(rotation = 75)
plt.legend()
plt.show()

# %% [markdown]
# We can use pyplot to create a bar plot that shows the correlation between Methane emissions and electricity production from hydroelectric sources across all regions. The plot will demonstrate the Methane emissions and electricity production from hydroelectric sources, with North America having the lowest values, while Sub-Saharan Africa having the highest.
#
# This bar plot will be based on data collected from all regions between 2000 and 2021. By visualizing the Methane emissions and hydroelectric electricity production data, we can identify which regions have the highest and lowest values. This information can help in understanding the distribution of Methane emissions and hydroelectric electricity production across different regions.
#
# The bar plot will be useful in identifying the patterns and trends in Methane emissions and hydroelectric electricity production over time. This information can be utilized to make informed decisions and implement effective policies that aim to minimize Methane emissions and increase hydroelectric electricity production.

# %% [markdown]
# #### Population growth and Urban population growth all Country

# %%
plt.figure(figsize=(15,7))
fig, ax = plt.subplots()
ax.bar(df["country"],df["Population growth"],label="Population growth")
ax.bar(df["country"],df["Urban population growth"],label="Urban population growth")
ax.set_xlabel('Country')
ax.set_ylabel('')
plt.title(label='Population growth and Urban population growth all Country')
plt.xticks(rotation = 75)
plt.legend()
plt.show()

# %% [markdown]
# We can utilize the pyplot library in Python to create a bar plot that showcases the relationship between Population Growth and Urban Population Growth across all countries. The plot will illustrate the lowest Population Growth and Urban Population Growth for France, while the highest values for both metrics will be observed in Zambia and Bangladesh.
#
# This plot will enable us to visualize the Population Growth and Urban Population Growth for all countries from 2000 to 2021. By examining the bar plot, we can quickly identify the countries with the lowest and highest values for both metrics, providing us with valuable insights into global population trends.

# %% [markdown]
# #### Histogram of Agricultural land (sq. km)

# %%
sns.distplot(x=df['Agricultural land (sq. km)'])
plt.xlabel('Agricultural land (sq. km)')
plt.title('Histogram of Agricultural land (sq. km)')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Upon analyzing the histogram, we can notice a prominent peak in the distribution centered around the range of Agricultural land from 0 to 0.2, with a density of roughly 0.02. It's worth noting that this histogram does not exhibit a bell-shaped distribution, hence it cannot be considered a normalized distribution.
#
# The histogram illustrates that Agricultural land remained relatively consistent across all countries from 2000 to 2021, with most countries having a flat distribution of Agricultural land. These findings provide insights into global agricultural trends and can aid in identifying areas where agricultural land use may require further examination or attention.

# %% [markdown]
# #### Histogram of Access to Electricity

# %%
sns.distplot(x=df['access to electricity'])
plt.xlabel('access to electricity')
plt.title('Histogram of Access to Electricity')
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Upon analyzing the histogram, it becomes evident that there is a significant concentration of data in the range of 90 to 100 for access to electricity, with a density of approximately 80 to 120. It's worth noting that the histogram is not normalized, and a bell shape is not apparent.
#
# The distribution of access to electricity appears to be mostly flat and skewed towards the left across all countries from 2000 to 2021. These observations suggest that while there has been progress in expanding access to electricity, there is still a significant portion of the global population that lacks access to this essential resource.

# %% [markdown]
# #### Scatter plot between Energy use and Eelectic Power Consumpotion With Region wise

# %%
sns.scatterplot(x=df["Energy use"],y=df["EPC"],hue=df['region'])
plt.xlabel('Energy use')
plt.ylabel('EPC')
plt.title(label='Scatter plot between Energy use and Eelectic Power Consumpotion With Region wise')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# This plot represents a Scatter plot that displays the correlation between Energy Use and Electric Power Consumption across different regions. The plot illustrates that the relationship between Energy Use and Electric Power Consumption has a positive mean trend, indicating that as one variable increases, the other also tends to increase.
#
# Upon closer examination, it is evident that the Energy Use and Electric Power Consumption have a particularly close relationship in North America from 2000 to 2021, implying that there is a strong correlation between these two variables in the region.
#
# In summary, the Scatter plot analysis reveals that there is a positive relationship between Energy Use and Electric Power Consumption across regions. Moreover, North America has the closest correlation between Energy Use and Electric Power Consumption from 2000 to 2021, highlighting the importance of understanding the relationship between these variables to ensure sustainable energy consumption practices.

# %% [markdown]
# #### Scatter plot between CO2 emissions (kt) and Energy use With Region wise

# %%
sns.scatterplot(x=df["CO2 emissions (kt)"],y=df["Energy use"],hue=df['region'])
plt.xlabel('CO2 emissions (kt)')
plt.ylabel('Energy use')
plt.title(label='Scatter plot between CO2 emissions (kt) and Energy use With Region wise')
plt.xticks(rotation = 75)
plt.show()

# %% [markdown]
# This plot is a Scatter plot that depicts the correlation between CO2 emissions (kt) and Energy Use across different regions. However, it is apparent that there is no positive relationship between the two variables for each data point. In other words, there is no observable correlation between CO2 emissions (kt) and Energy Use across regions from 2000 to 2021.
#
# Despite analyzing the plot, it is clear that there is no relationship between CO2 emissions (kt) and Energy Use across all regions. Therefore, this plot suggests that the factors affecting CO2 emissions (kt) and Energy Use may not be related, and further investigation may be necessary to understand the relationship between the two variables better.
#
# In conclusion, this Scatter plot analysis indicates that there is no observable positive relationship between CO2 emissions (kt) and Energy Use across different regions from 2000 to 2021. Therefore, it is necessary to explore other factors that may impact CO2 emissions to develop effective strategies for reducing global carbon emissions.

# %% [markdown]
# #### Heatmap

# %%
# Create dataframe of the all Quantitative Indicators
df1=df.iloc[:, 5:22]
# Create correlation Matrix
df2=df1.corr()
# Create Heatmap all indicators from Correlation Matrix
plt.figure(figsize=(8,8))
sns.heatmap(df2.corr(),linewidth=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This plot is a heatmap generated using the seaborn library that displays the correlation matrix between various climate change indicators. Each climate change indicator's correlation with other indicators is computed to obtain this matrix.
#
# Upon analyzing the heatmap, it is evident that two indicators are negatively correlated, which is indicated by the black boxes. In contrast, the red boxes represent a positive correlation between the indicators. The two black boxes located closely to each other indicate a strong negative correlation between the respective indicators. This implies that when one of the indicators increases, the other indicator tends to decrease.
#
# On the other hand, the red boxes indicate a good positive correlation between the indicators. This means that when one of the indicators increases, the other indicator also tends to increase. Therefore, the red boxes suggest that there is a strong relationship between these indicators, which can help in predicting one indicator's behavior based on another.
